# %% [markdown]
# # 'Reproducing' the Third Figure from the Lunch Talk (with Unresolved Multiplicity) (No additional IFMR) With Salpeter 1955-style IMF used.
# In this test notebook, I will examine the code that should create the juxtaposed KLF's of stars from the Galacitc Center and from their MIST and BPASS cluster counterparts. Final product should be similar to Figure 1 in Lu et al. 2013.
#
# Firstly, I grab some code from the  jlu_python/jlu/papers/lu_gc_imf.py directory in the Moving Universe Lab's computers.

# %%
# After spending a bit of time figuring out how pickling files and loading works
# I have finally done it.

# These come from 
import pickle
import sys
from spisea import evolution

class dat:
    datin = "Description: Container of Data"

def load_klf_by_radius(rmin=0, rmax=30, mask_for_log=False):
    pickleFile = ('%sklf_r_%.1f_%.1f.dat' %
                  ('/Users/jlu/work/gc/imf/klf/current/', rmin, rmax))
    _in = open(pickleFile, 'rb')
    d = dat()
    d.Kp = pickle.load(_in,encoding='bytes')
    d.N = pickle.load(_in, encoding='bytes')
    d.eN = pickle.load(_in, encoding='bytes')

    d.N_ext = pickle.load(_in, encoding='bytes')
    d.eN_ext = pickle.load(_in, encoding='bytes')

    d.N_ext_cmp_sp = pickle.load(_in, encoding='bytes')
    d.eN_ext_cmp_sp = pickle.load(_in, encoding='bytes')

    d.N_ext_cmp_sp_im = pickle.load(_in, encoding='bytes')
    d.eN_ext_cmp_sp_im = pickle.load(_in, encoding='bytes')

    d.KLF = pickle.load(_in, encoding='bytes')
    d.eKLF = pickle.load(_in, encoding='bytes')

    d.KLF_ext = pickle.load(_in,
                            encoding='bytes')
    d.eKLF_ext = pickle.load(_in,
                             encoding='bytes')

    d.KLF_ext_cmp_sp = pickle.load(_in, encoding='bytes')
    d.eKLF_ext_cmp_sp = pickle.load(_in, encoding='bytes')

    d.KLF_ext_cmp_sp_im = pickle.load(_in,
                                      encoding='bytes')
    d.eKLF_ext_cmp_sp_im = pickle.load(_in,
                                       encoding='bytes')

    d.N_noWR = pickle.load(_in, encoding='bytes')
    d.eN_noWR = pickle.load(_in, encoding='bytes')

    d.N_ext_noWR = pickle.load(_in, encoding='bytes')
    d.eN_ext_noWR = pickle.load(_in, encoding='bytes')

    d.N_ext_cmp_sp_noWR = pickle.load(_in,
                                      encoding='bytes')
    d.eN_ext_cmp_sp_noWR = pickle.load(_in,
                                       encoding='bytes')

    d.N_ext_cmp_sp_im_noWR = pickle.load(_in,
                                         encoding='bytes')
    d.eN_ext_cmp_sp_im_noWR = pickle.load(_in,
                                          encoding='bytes')

    d.KLF_noWR = pickle.load(_in, encoding='bytes')
    d.eKLF_noWR = pickle.load(_in, encoding='bytes')

    d.KLF_ext_noWR = pickle.load(_in, encoding='bytes')
    d.eKLF_ext_noWR = pickle.load(_in, encoding='bytes')

    d.KLF_ext_cmp_sp_noWR = pickle.load(_in,
                                        encoding='bytes')
    d.eKLF_ext_cmp_sp_noWR = pickle.load(_in,
                                         encoding='bytes')

    d.KLF_ext_cmp_sp_im_noWR = pickle.load(_in,
                                           encoding='bytes')
    d.eKLF_ext_cmp_sp_im_noWR = pickle.load(_in,
                                            encoding='bytes')

    d.comp_spec_ext = pickle.load(_in, encoding='bytes')
    d.comp_imag_ext = pickle.load(_in, encoding='bytes')

    if mask_for_log:
        # Repair for zeros since we are plotting in semi-log-y
        d.eN = np.ma.masked_where(d.N <= 0, d.eN)
        d.N = np.ma.masked_where(d.N <= 0, d.N)

        d.eN_ext = np.ma.masked_where(d.N_ext <= 0, d.eN_ext)
        d.N_ext = np.ma.masked_where(d.N_ext <= 0, d.N_ext)

        d.eN_ext_cmp_sp = np.ma.masked_where(d.N_ext_cmp_sp <=
                                             0, d.eN_ext_cmp_sp)
        d.N_ext_cmp_sp = np.ma.masked_where(d.N_ext_cmp_sp <=
                                            0, d.N_ext_cmp_sp)

        d.eN_ext_cmp_sp_im = np.ma.masked_where(d.N_ext_cmp_sp_im <=
                                                0, d.eN_ext_cmp_sp_im)
        d.N_ext_cmp_sp_im = np.ma.masked_where(d.N_ext_cmp_sp_im <=
                                               0, d.N_ext_cmp_sp_im)
        
        d.eKLF = np.ma.masked_where(d.KLF <= 0, d.eKLF)
        d.KLF = np.ma.masked_where(d.KLF <= 0, d.KLF)
        
        d.eKLF_ext = np.ma.masked_where(d.KLF_ext <= 0,
                                        d.eKLF_ext)
        d.KLF_ext = np.ma.masked_where(d.KLF_ext <= 0,
                                       d.KLF_ext)
        
        d.eKLF_ext_cmp_sp = np.ma.masked_where(d.KLF_ext_cmp_sp <= 0, 
                                               d.eKLF_ext_cmp_sp)
        d.KLF_ext_cmp_sp = np.ma.masked_where(d.KLF_ext_cmp_sp <= 0, 
                                              d.KLF_ext_cmp_sp)
        
        d.eKLF_ext_cmp_sp_im = (np.ma.
                                masked_where(d.KLF_ext_cmp_sp_im <=
                                             0, d.eKLF_ext_cmp_sp_im))
        d.KLF_ext_cmp_sp_im = (np.ma.
                               masked_where(d.KLF_ext_cmp_sp_im <=
                                            0, d.KLF_ext_cmp_sp_im))


    _in.close()

    return d

# %% [markdown]
# The following line loads data from /Users/jlu/work/gc/imf/klf/current/klf_r_0.0_30.0.dat. Recall I use the noWR option as the corresponding figure

# %%
import numpy as np
result = load_klf_by_radius(mask_for_log=True)
magBin = result.Kp[1] - result.Kp[0]
# Note that the < 16 comes from the original code!
idx = np.where(result.Kp < 16)[0]

# %% [markdown]
# Now, I create the BPASS isochrone for that specific age. $10^{6.78}$  years of age (around 6 million years). From that isochrone, I will create a cluster using an IMF of $\alpha = 1.7$.

# %%
from spisea import synthetic
BPASS_iso = synthetic.Isochrone_Binary(6.78, 2.7,
                                       8000, 0.0, filters=['nirc2,Kp'])
# Out:
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /g/lu/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/pysynphot/refs.py:125: UserWarning: No thermal tables found, no thermal calculations can be performed. No files found for /g/lu/models/cdbs/mtab/*_tmt.fits
#   'no thermal calculations can be performed. ' + str(e))
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /u/ryotainagaki/Desktop/PyPopStar/spisea/evolution.py:1794: RuntimeWarning: overflow encountered in power
#   (1 / cs.au) * un.m)
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/units/quantity.py:479: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/units/quantity.py:479: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Changing to logg=3.50 for T= 26935 logg=3.29
# Changing to T= 50000 for T= 50518 logg=3.84
# Changing to logg=5.00 for T= 50518 logg=3.84
# Changing to T= 50000 for T=168628 logg=5.83
# Changing to logg=5.00 for T=168628 logg=5.83
# Changing to logg=3.50 for T= 27821 logg=3.39
# Changing to T= 50000 for T=166073 logg=5.80
# Changing to logg=5.00 for T=166073 logg=5.80
# Changing to T= 50000 for T=162596 logg=5.78
# Changing to logg=5.00 for T=162596 logg=5.78
# Changing to logg=3.00 for T= 23226 logg=2.95
# Changing to T= 50000 for T=169071 logg=5.83
# Changing to logg=5.00 for T=169071 logg=5.83
# Changing to T= 50000 for T=166855 logg=5.80
# Changing to logg=5.00 for T=166855 logg=5.80
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=143840 logg=5.56
# Changing to logg=5.00 for T=143840 logg=5.56
# Changing to T= 50000 for T=113794 logg=5.39
# Changing to logg=5.00 for T=113794 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113078 logg=5.38
# Changing to logg=5.00 for T=113078 logg=5.38
# Changing to T= 50000 for T=113138 logg=5.07
# Changing to logg=5.00 for T=113138 logg=5.07
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=114427 logg=5.39
# Changing to logg=5.00 for T=114427 logg=5.39
# Changing to T= 50000 for T=114204 logg=5.39
# Changing to logg=5.00 for T=114204 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=112980 logg=5.29
# Changing to logg=5.00 for T=112980 logg=5.29
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 38122 logg=3.86
# Changing to T= 50000 for T=115414 logg=5.37
# Changing to logg=5.00 for T=115414 logg=5.37
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=143698 logg=5.56
# Changing to logg=5.00 for T=143698 logg=5.56
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=141579 logg=5.54
# Changing to logg=5.00 for T=141579 logg=5.54
# Changing to T= 50000 for T=170243 logg=5.83
# Changing to logg=5.00 for T=170243 logg=5.83
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=142564 logg=5.55
# Changing to logg=5.00 for T=142564 logg=5.55
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113810 logg=5.38
# Changing to logg=5.00 for T=113810 logg=5.38
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=139213 logg=5.51
# Changing to logg=5.00 for T=139213 logg=5.51
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=114283 logg=5.38
# Changing to logg=5.00 for T=114283 logg=5.38
# Changing to T= 50000 for T=170514 logg=5.85
# Changing to logg=5.00 for T=170514 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=114198 logg=5.39
# Changing to logg=5.00 for T=114198 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=139357 logg=5.51
# Changing to logg=5.00 for T=139357 logg=5.51
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=173488 logg=5.87
# Changing to logg=5.00 for T=173488 logg=5.87
# Changing to T= 50000 for T=143364 logg=5.56
# Changing to logg=5.00 for T=143364 logg=5.56
# Changing to T= 50000 for T=113729 logg=5.40
# Changing to logg=5.00 for T=113729 logg=5.40
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26382 logg=3.26
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171933 logg=5.86
# Changing to logg=5.00 for T=171933 logg=5.86
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=132850 logg=5.43
# Changing to logg=5.00 for T=132850 logg=5.43
# Changing to T= 50000 for T=172910 logg=5.87
# Changing to logg=5.00 for T=172910 logg=5.87
# Changing to T= 50000 for T=144521 logg=5.57
# Changing to logg=5.00 for T=144521 logg=5.57
# Changing to logg=4.00 for T= 34533 logg=3.99
# Changing to logg=3.50 for T= 27699 logg=3.38
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=139566 logg=5.51
# Changing to logg=5.00 for T=139566 logg=5.51
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=138392 logg=5.50
# Changing to logg=5.00 for T=138392 logg=5.50
# Changing to T= 50000 for T=113839 logg=5.39
# Changing to logg=5.00 for T=113839 logg=5.39
# Changing to logg=4.00 for T= 31586 logg=3.71
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113271 logg=5.38
# Changing to logg=5.00 for T=113271 logg=5.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=110311 logg=5.42
# Changing to logg=5.00 for T=110311 logg=5.42
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=132096 logg=5.42
# Changing to logg=5.00 for T=132096 logg=5.42
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28534 logg=3.45
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=113902 logg=5.38
# Changing to logg=5.00 for T=113902 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113076 logg=5.39
# Changing to logg=5.00 for T=113076 logg=5.39
# Changing to T= 50000 for T=141394 logg=5.53
# Changing to logg=5.00 for T=141394 logg=5.53
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113941 logg=5.39
# Changing to logg=5.00 for T=113941 logg=5.39
# Changing to T= 50000 for T=137727 logg=5.51
# Changing to logg=5.00 for T=137727 logg=5.51
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=142978 logg=5.55
# Changing to logg=5.00 for T=142978 logg=5.55
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=113441 logg=5.38
# Changing to logg=5.00 for T=113441 logg=5.38
# Changing to T= 50000 for T=133076 logg=5.44
# Changing to logg=5.00 for T=133076 logg=5.44
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27547 logg=3.37
# Changing to logg=4.00 for T= 38775 logg=3.87
# Changing to T= 50000 for T=114233 logg=5.39
# Changing to logg=5.00 for T=114233 logg=5.39
# Changing to logg=4.00 for T= 31715 logg=3.91
# Changing to logg=3.00 for T= 23031 logg=2.72
# Changing to logg=3.50 for T= 28760 logg=3.16
# Changing to T= 50000 for T=115321 logg=5.37
# Changing to logg=5.00 for T=115321 logg=5.37
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T= 57298 logg=3.98
# Changing to logg=5.00 for T= 57298 logg=3.98
# Changing to T= 50000 for T=139489 logg=5.51
# Changing to logg=5.00 for T=139489 logg=5.51
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=113941 logg=5.39
# Changing to logg=5.00 for T=113941 logg=5.39
# Changing to T= 50000 for T=142249 logg=5.54
# Changing to logg=5.00 for T=142249 logg=5.54
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 34990 logg=3.71
# Changing to T= 50000 for T=138685 logg=5.50
# Changing to logg=5.00 for T=138685 logg=5.50
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=143407 logg=5.56
# Changing to logg=5.00 for T=143407 logg=5.56
# Changing to T= 50000 for T=143632 logg=5.56
# Changing to logg=5.00 for T=143632 logg=5.56
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=143863 logg=5.56
# Changing to logg=5.00 for T=143863 logg=5.56
# Changing to T= 50000 for T=142485 logg=5.55
# Changing to logg=5.00 for T=142485 logg=5.55
# Changing to T= 50000 for T=164608 logg=5.79
# Changing to logg=5.00 for T=164608 logg=5.79
# Changing to T= 50000 for T=142787 logg=5.55
# Changing to logg=5.00 for T=142787 logg=5.55
# Changing to T= 50000 for T=172604 logg=5.86
# Changing to logg=5.00 for T=172604 logg=5.86
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113933 logg=5.38
# Changing to logg=5.00 for T=113933 logg=5.38
# Changing to T= 50000 for T=113692 logg=5.38
# Changing to logg=5.00 for T=113692 logg=5.38
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=111504 logg=5.38
# Changing to logg=5.00 for T=111504 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 31661 logg=3.55
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T= 67616 logg=4.36
# Changing to logg=5.00 for T= 67616 logg=4.36
# Changing to logg=4.00 for T= 31409 logg=3.56
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113253 logg=5.39
# Changing to logg=5.00 for T=113253 logg=5.39
# Changing to T= 50000 for T=142331 logg=5.55
# Changing to logg=5.00 for T=142331 logg=5.55
# Changing to T= 50000 for T=113496 logg=5.38
# Changing to logg=5.00 for T=113496 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 35655 logg=3.64
# Changing to logg=4.00 for T= 33383 logg=3.68
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=170699 logg=5.84
# Changing to logg=5.00 for T=170699 logg=5.84
# Changing to T= 50000 for T=173404 logg=5.87
# Changing to logg=5.00 for T=173404 logg=5.87
# Changing to logg=3.00 for T= 23516 logg=2.68
# Changing to T= 50000 for T=114214 logg=5.38
# Changing to logg=5.00 for T=114214 logg=5.38
# Changing to logg=3.50 for T= 30934 logg=3.46
# Changing to T= 50000 for T=143380 logg=5.56
# Changing to logg=5.00 for T=143380 logg=5.56
# Changing to logg=4.50 for T= 39506 logg=3.82
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=139293 logg=5.51
# Changing to logg=5.00 for T=139293 logg=5.51
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=114196 logg=5.33
# Changing to logg=5.00 for T=114196 logg=5.33
# Changing to T= 50000 for T=114916 logg=5.10
# Changing to logg=5.00 for T=114916 logg=5.10
# Changing to T= 50000 for T=113553 logg=5.38
# Changing to logg=5.00 for T=113553 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=133177 logg=5.43
# Changing to logg=5.00 for T=133177 logg=5.43
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=170530 logg=5.84
# Changing to logg=5.00 for T=170530 logg=5.84
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27374 logg=3.36
# Changing to T= 50000 for T=141831 logg=5.54
# Changing to logg=5.00 for T=141831 logg=5.54
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 34598 logg=3.91
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27607 logg=3.32
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=113451 logg=5.39
# Changing to logg=5.00 for T=113451 logg=5.39
# Changing to T= 50000 for T=114093 logg=5.39
# Changing to logg=5.00 for T=114093 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=2.50 for T= 15679 logg=1.76
# Changing to logg=4.00 for T= 32563 logg=3.81
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T= 79554 logg=4.57
# Changing to logg=5.00 for T= 79554 logg=4.57
# Changing to T= 50000 for T=157134 logg=5.71
# Changing to logg=5.00 for T=157134 logg=5.71
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=138096 logg=5.49
# Changing to logg=5.00 for T=138096 logg=5.49
# Changing to T= 50000 for T=139111 logg=5.51
# Changing to logg=5.00 for T=139111 logg=5.51
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=133122 logg=5.43
# Changing to logg=5.00 for T=133122 logg=5.43
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=139348 logg=5.51
# Changing to logg=5.00 for T=139348 logg=5.51
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27363 logg=3.34
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=147055 logg=5.60
# Changing to logg=5.00 for T=147055 logg=5.60
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 34127 logg=3.82
# Changing to T= 50000 for T=144085 logg=5.57
# Changing to logg=5.00 for T=144085 logg=5.57
# Changing to T= 50000 for T=113682 logg=5.39
# Changing to logg=5.00 for T=113682 logg=5.39
# Changing to T= 50000 for T=113907 logg=5.39
# Changing to logg=5.00 for T=113907 logg=5.39
# Changing to logg=4.00 for T= 35270 logg=3.69
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=114188 logg=5.39
# Changing to logg=5.00 for T=114188 logg=5.39
# Changing to logg=3.50 for T= 26386 logg=3.25
# Changing to T= 50000 for T=130443 logg=5.40
# Changing to logg=5.00 for T=130443 logg=5.40
# Changing to T= 50000 for T=113844 logg=5.38
# Changing to logg=5.00 for T=113844 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=141462 logg=5.54
# Changing to logg=5.00 for T=141462 logg=5.54
# Changing to T= 50000 for T=172922 logg=5.86
# Changing to logg=5.00 for T=172922 logg=5.86
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=114148 logg=5.39
# Changing to logg=5.00 for T=114148 logg=5.39
# Changing to T= 50000 for T=113457 logg=5.38
# Changing to logg=5.00 for T=113457 logg=5.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=114296 logg=5.39
# Changing to logg=5.00 for T=114296 logg=5.39
# Changing to T= 50000 for T=130242 logg=5.40
# Changing to logg=5.00 for T=130242 logg=5.40
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=140883 logg=5.53
# Changing to logg=5.00 for T=140883 logg=5.53
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 28403 logg=3.48
# Changing to T= 50000 for T=128869 logg=5.38
# Changing to logg=5.00 for T=128869 logg=5.38
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=142939 logg=5.55
# Changing to logg=5.00 for T=142939 logg=5.55
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=113702 logg=5.38
# Changing to logg=5.00 for T=113702 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113467 logg=5.39
# Changing to logg=5.00 for T=113467 logg=5.39
# Changing to logg=3.50 for T= 28706 logg=3.49
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=138810 logg=5.50
# Changing to logg=5.00 for T=138810 logg=5.50
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=138848 logg=5.50
# Changing to logg=5.00 for T=138848 logg=5.50
# Changing to logg=3.50 for T= 28561 logg=3.08
# Changing to T= 50000 for T=113538 logg=5.39
# Changing to logg=5.00 for T=113538 logg=5.39
# Changing to T= 50000 for T=114217 logg=5.39
# Changing to logg=5.00 for T=114217 logg=5.39
# Changing to logg=4.00 for T= 38898 logg=3.92
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 32249 logg=3.68
# Changing to T= 50000 for T=162611 logg=5.76
# Changing to logg=5.00 for T=162611 logg=5.76
# Changing to T= 50000 for T=112764 logg=5.31
# Changing to logg=5.00 for T=112764 logg=5.31
# Changing to T= 50000 for T=114446 logg=5.33
# Changing to logg=5.00 for T=114446 logg=5.33
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=142046 logg=5.54
# Changing to logg=5.00 for T=142046 logg=5.54
# Changing to logg=3.50 for T= 26900 logg=3.28
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27668 logg=3.26
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=131283 logg=5.41
# Changing to logg=5.00 for T=131283 logg=5.41
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=4.00 for T= 37292 logg=3.75
# Changing to T= 50000 for T=169985 logg=5.83
# Changing to logg=5.00 for T=169985 logg=5.83
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113522 logg=5.38
# Changing to logg=5.00 for T=113522 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=147577 logg=5.60
# Changing to logg=5.00 for T=147577 logg=5.60
# Changing to T= 50000 for T= 51042 logg=3.86
# Changing to logg=5.00 for T= 51042 logg=3.86
# Changing to T= 50000 for T=140243 logg=5.52
# Changing to logg=5.00 for T=140243 logg=5.52
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=140647 logg=5.52
# Changing to logg=5.00 for T=140647 logg=5.52
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=170349 logg=5.84
# Changing to logg=5.00 for T=170349 logg=5.84
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28177 logg=3.34
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=113983 logg=5.39
# Changing to logg=5.00 for T=113983 logg=5.39
# Changing to T= 50000 for T=113464 logg=5.39
# Changing to logg=5.00 for T=113464 logg=5.39
# Changing to T= 50000 for T=132941 logg=5.43
# Changing to logg=5.00 for T=132941 logg=5.43
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=113925 logg=5.38
# Changing to logg=5.00 for T=113925 logg=5.38
# Changing to T= 50000 for T=110443 logg=5.41
# Changing to logg=5.00 for T=110443 logg=5.41
# Changing to T= 50000 for T=113300 logg=5.38
# Changing to logg=5.00 for T=113300 logg=5.38
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26055 logg=3.21
# Changing to T= 50000 for T=141906 logg=5.54
# Changing to logg=5.00 for T=141906 logg=5.54
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27538 logg=3.37
# Changing to logg=3.50 for T= 29771 logg=3.49
# Changing to T= 50000 for T=164850 logg=5.79
# Changing to logg=5.00 for T=164850 logg=5.79
# Changing to T= 50000 for T=113967 logg=5.39
# Changing to logg=5.00 for T=113967 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26949 logg=3.30
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.50 for T= 40899 logg=3.46
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 36450 logg=3.84
# Changing to T= 50000 for T=113423 logg=5.38
# Changing to logg=5.00 for T=113423 logg=5.38
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 26690 logg=3.30
# Changing to T= 50000 for T=115138 logg=5.36
# Changing to logg=5.00 for T=115138 logg=5.36
# Changing to T= 50000 for T=173285 logg=5.87
# Changing to logg=5.00 for T=173285 logg=5.87
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=114238 logg=5.39
# Changing to logg=5.00 for T=114238 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=179800 logg=5.91
# Changing to logg=5.00 for T=179800 logg=5.91
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113050 logg=5.39
# Changing to logg=5.00 for T=113050 logg=5.39
# Changing to T= 50000 for T=110997 logg=5.38
# Changing to logg=5.00 for T=110997 logg=5.38
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=130260 logg=5.40
# Changing to logg=5.00 for T=130260 logg=5.40
# Changing to T= 50000 for T=111972 logg=5.39
# Changing to logg=5.00 for T=111972 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=143665 logg=5.56
# Changing to logg=5.00 for T=143665 logg=5.56
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=175049 logg=5.89
# Changing to logg=5.00 for T=175049 logg=5.89
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 36644 logg=3.81
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=142236 logg=5.54
# Changing to logg=5.00 for T=142236 logg=5.54
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=170141 logg=5.83
# Changing to logg=5.00 for T=170141 logg=5.83
# Changing to T= 50000 for T=171878 logg=5.85
# Changing to logg=5.00 for T=171878 logg=5.85
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113794 logg=5.38
# Changing to logg=5.00 for T=113794 logg=5.38
# Changing to logg=4.00 for T= 37720 logg=3.84
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=173010 logg=5.87
# Changing to logg=5.00 for T=173010 logg=5.87
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=173014 logg=5.86
# Changing to logg=5.00 for T=173014 logg=5.86
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=176405 logg=5.89
# Changing to logg=5.00 for T=176405 logg=5.89
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=142180 logg=5.54
# Changing to logg=5.00 for T=142180 logg=5.54
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=114164 logg=5.39
# Changing to logg=5.00 for T=114164 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=143126 logg=5.56
# Changing to logg=5.00 for T=143126 logg=5.56
# Changing to logg=3.50 for T= 27364 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28333 logg=3.43
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113402 logg=5.38
# Changing to logg=5.00 for T=113402 logg=5.38
# Changing to T= 50000 for T=174405 logg=5.88
# Changing to logg=5.00 for T=174405 logg=5.88
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=145231 logg=5.58
# Changing to logg=5.00 for T=145231 logg=5.58
# Changing to logg=3.00 for T= 23591 logg=2.98
# Changing to logg=3.00 for T= 23728 logg=2.99
# Changing to T= 50000 for T=138532 logg=5.50
# Changing to logg=5.00 for T=138532 logg=5.50
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27689 logg=3.35
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=138749 logg=5.50
# Changing to logg=5.00 for T=138749 logg=5.50
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=143212 logg=5.56
# Changing to logg=5.00 for T=143212 logg=5.56
# Changing to logg=4.00 for T= 37424 logg=3.76
# Changing to T= 50000 for T=113462 logg=5.39
# Changing to logg=5.00 for T=113462 logg=5.39
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 27909 logg=3.40
# Changing to T= 50000 for T=109906 logg=5.39
# Changing to logg=5.00 for T=109906 logg=5.39
# Changing to logg=3.50 for T= 26620 logg=3.27
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=141674 logg=5.54
# Changing to logg=5.00 for T=141674 logg=5.54
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=143239 logg=5.56
# Changing to logg=5.00 for T=143239 logg=5.56
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113823 logg=5.38
# Changing to logg=5.00 for T=113823 logg=5.38
# Changing to T= 50000 for T=111158 logg=5.38
# Changing to logg=5.00 for T=111158 logg=5.38
# Changing to logg=3.50 for T= 28208 logg=3.45
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=172242 logg=5.86
# Changing to logg=5.00 for T=172242 logg=5.86
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=163667 logg=5.77
# Changing to logg=5.00 for T=163667 logg=5.77
# Changing to logg=3.50 for T= 27546 logg=3.34
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=173014 logg=5.87
# Changing to logg=5.00 for T=173014 logg=5.87
# Changing to T= 50000 for T=143377 logg=5.56
# Changing to logg=5.00 for T=143377 logg=5.56
# Changing to T= 50000 for T=136330 logg=5.49
# Changing to logg=5.00 for T=136330 logg=5.49
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 31328 logg=3.57
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113543 logg=5.38
# Changing to logg=5.00 for T=113543 logg=5.38
# Changing to T= 50000 for T=113823 logg=5.38
# Changing to logg=5.00 for T=113823 logg=5.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=135816 logg=5.49
# Changing to logg=5.00 for T=135816 logg=5.49
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27733 logg=3.33
# Changing to T= 50000 for T=130671 logg=5.40
# Changing to logg=5.00 for T=130671 logg=5.40
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=140543 logg=5.52
# Changing to logg=5.00 for T=140543 logg=5.52
# Changing to T= 50000 for T=134478 logg=5.44
# Changing to logg=5.00 for T=134478 logg=5.44
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.50 for T= 39023 logg=3.96
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=141752 logg=5.54
# Changing to logg=5.00 for T=141752 logg=5.54
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 36378 logg=3.73
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=125698 logg=5.43
# Changing to logg=5.00 for T=125698 logg=5.43
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 35888 logg=3.64
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=114575 logg=5.39
# Changing to logg=5.00 for T=114575 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 32165 logg=3.65
# Changing to T= 50000 for T=112536 logg=5.28
# Changing to logg=5.00 for T=112536 logg=5.28
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=112026 logg=5.39
# Changing to logg=5.00 for T=112026 logg=5.39
# Changing to T= 50000 for T=138542 logg=5.50
# Changing to logg=5.00 for T=138542 logg=5.50
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=110517 logg=5.39
# Changing to logg=5.00 for T=110517 logg=5.39
# Changing to T= 50000 for T=143850 logg=5.56
# Changing to logg=5.00 for T=143850 logg=5.56
# Changing to T= 50000 for T=113750 logg=5.38
# Changing to logg=5.00 for T=113750 logg=5.38
# Changing to T= 50000 for T=143255 logg=5.56
# Changing to logg=5.00 for T=143255 logg=5.56
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113561 logg=5.38
# Changing to logg=5.00 for T=113561 logg=5.38
# Changing to logg=4.00 for T= 32256 logg=3.62
# Changing to T= 50000 for T=114248 logg=5.39
# Changing to logg=5.00 for T=114248 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27203 logg=3.33
# Changing to T= 50000 for T=115006 logg=5.36
# Changing to logg=5.00 for T=115006 logg=5.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=170514 logg=5.84
# Changing to logg=5.00 for T=170514 logg=5.84
# Changing to T= 50000 for T=113564 logg=5.38
# Changing to logg=5.00 for T=113564 logg=5.38
# Changing to T= 50000 for T=141491 logg=5.54
# Changing to logg=5.00 for T=141491 logg=5.54
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 31140 logg=3.57
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.00 for T= 22903 logg=2.75
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171648 logg=5.85
# Changing to logg=5.00 for T=171648 logg=5.85
# Changing to T= 50000 for T=140556 logg=5.53
# Changing to logg=5.00 for T=140556 logg=5.53
# Changing to T= 50000 for T=113616 logg=5.38
# Changing to logg=5.00 for T=113616 logg=5.38
# Changing to logg=4.50 for T= 44832 logg=3.62
# Changing to logg=3.50 for T= 29252 logg=3.49
# Changing to T= 50000 for T=141449 logg=5.54
# Changing to logg=5.00 for T=141449 logg=5.54
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 32415 logg=3.40
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26836 logg=3.29
# Changing to T= 50000 for T=114120 logg=5.39
# Changing to logg=5.00 for T=114120 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27538 logg=3.37
# Changing to T= 50000 for T=112969 logg=5.39
# Changing to logg=5.00 for T=112969 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28494 logg=3.32
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113561 logg=5.38
# Changing to logg=5.00 for T=113561 logg=5.38
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=132593 logg=5.42
# Changing to logg=5.00 for T=132593 logg=5.42
# Changing to T= 50000 for T=170954 logg=5.84
# Changing to logg=5.00 for T=170954 logg=5.84
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=114425 logg=5.39
# Changing to logg=5.00 for T=114425 logg=5.39
# Changing to T= 50000 for T=143087 logg=5.55
# Changing to logg=5.00 for T=143087 logg=5.55
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=165501 logg=5.80
# Changing to logg=5.00 for T=165501 logg=5.80
# Changing to T= 50000 for T=138723 logg=5.50
# Changing to logg=5.00 for T=138723 logg=5.50
# Changing to logg=4.00 for T= 36882 logg=3.76
# Changing to logg=4.00 for T= 32721 logg=3.72
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=170114 logg=5.84
# Changing to logg=5.00 for T=170114 logg=5.84
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=173684 logg=5.87
# Changing to logg=5.00 for T=173684 logg=5.87
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=114135 logg=5.39
# Changing to logg=5.00 for T=114135 logg=5.39
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=4.00 for T= 34795 logg=3.86
# Changing to T= 50000 for T=119034 logg=5.36
# Changing to logg=5.00 for T=119034 logg=5.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=143407 logg=5.56
# Changing to logg=5.00 for T=143407 logg=5.56
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27427 logg=3.36
# Changing to T= 50000 for T=141720 logg=5.54
# Changing to logg=5.00 for T=141720 logg=5.54
# Changing to logg=3.50 for T= 28696 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=130506 logg=5.40
# Changing to logg=5.00 for T=130506 logg=5.40
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=178135 logg=5.86
# Changing to logg=5.00 for T=178135 logg=5.86
# Changing to T= 50000 for T=137727 logg=5.49
# Changing to logg=5.00 for T=137727 logg=5.49
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=141400 logg=5.53
# Changing to logg=5.00 for T=141400 logg=5.53
# Changing to T= 50000 for T=125667 logg=5.30
# Changing to logg=5.00 for T=125667 logg=5.30
# Changing to T= 50000 for T=114330 logg=5.39
# Changing to logg=5.00 for T=114330 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26555 logg=3.26
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=113773 logg=5.39
# Changing to logg=5.00 for T=113773 logg=5.39
# Changing to T= 50000 for T=132063 logg=5.42
# Changing to logg=5.00 for T=132063 logg=5.42
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=139428 logg=5.51
# Changing to logg=5.00 for T=139428 logg=5.51
# Changing to logg=3.50 for T= 26861 logg=3.29
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=131713 logg=5.41
# Changing to logg=5.00 for T=131713 logg=5.41
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=140952 logg=5.53
# Changing to logg=5.00 for T=140952 logg=5.53
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=113907 logg=5.39
# Changing to logg=5.00 for T=113907 logg=5.39
# Changing to logg=4.00 for T= 34657 logg=3.16
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=172381 logg=5.86
# Changing to logg=5.00 for T=172381 logg=5.86
# Changing to T= 50000 for T=113240 logg=5.39
# Changing to logg=5.00 for T=113240 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=113789 logg=5.38
# Changing to logg=5.00 for T=113789 logg=5.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.00 for T= 22218 logg=2.72
# Changing to T= 50000 for T=132440 logg=5.42
# Changing to logg=5.00 for T=132440 logg=5.42
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=172926 logg=5.86
# Changing to logg=5.00 for T=172926 logg=5.86
# Changing to T= 50000 for T=171941 logg=5.86
# Changing to logg=5.00 for T=171941 logg=5.86
# Changing to logg=4.00 for T= 38156 logg=3.88
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 32391 logg=3.82
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=169993 logg=5.83
# Changing to logg=5.00 for T=169993 logg=5.83
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 34002 logg=3.77
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=142807 logg=5.55
# Changing to logg=5.00 for T=142807 logg=5.55
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=169157 logg=5.83
# Changing to logg=5.00 for T=169157 logg=5.83
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to T= 50000 for T=137797 logg=5.49
# Changing to logg=5.00 for T=137797 logg=5.49
# Changing to T= 50000 for T=113457 logg=5.38
# Changing to logg=5.00 for T=113457 logg=5.38
# Changing to T= 50000 for T=113789 logg=5.38
# Changing to logg=5.00 for T=113789 logg=5.38
# Changing to logg=4.00 for T= 31929 logg=3.69
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 34038 logg=3.83
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.00 for T= 23260 logg=2.74
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=139268 logg=5.51
# Changing to logg=5.00 for T=139268 logg=5.51
# Changing to logg=3.50 for T= 27699 logg=3.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=2.50 for T= 16750 logg=2.11
# Changing to T= 50000 for T=131586 logg=5.41
# Changing to logg=5.00 for T=131586 logg=5.41
# Changing to T= 50000 for T=172326 logg=5.86
# Changing to logg=5.00 for T=172326 logg=5.86
# Changing to T= 50000 for T=114251 logg=5.39
# Changing to logg=5.00 for T=114251 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=110507 logg=5.40
# Changing to logg=5.00 for T=110507 logg=5.40
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=171957 logg=5.86
# Changing to logg=5.00 for T=171957 logg=5.86
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=114114 logg=5.39
# Changing to logg=5.00 for T=114114 logg=5.39
# Changing to T= 50000 for T=113556 logg=5.39
# Changing to logg=5.00 for T=113556 logg=5.39
# Changing to T= 50000 for T=138874 logg=5.50
# Changing to logg=5.00 for T=138874 logg=5.50
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=114138 logg=5.39
# Changing to logg=5.00 for T=114138 logg=5.39
# Changing to T= 50000 for T=114133 logg=5.39
# Changing to logg=5.00 for T=114133 logg=5.39
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=132459 logg=5.42
# Changing to logg=5.00 for T=132459 logg=5.42
# Changing to logg=3.50 for T= 26461 logg=3.26
# Changing to T= 50000 for T=132422 logg=5.42
# Changing to logg=5.00 for T=132422 logg=5.42
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=159386 logg=5.74
# Changing to logg=5.00 for T=159386 logg=5.74
# Changing to logg=3.50 for T= 28153 logg=3.25
# Changing to T= 50000 for T=142475 logg=5.55
# Changing to logg=5.00 for T=142475 logg=5.55
# Changing to T= 50000 for T=113595 logg=5.38
# Changing to logg=5.00 for T=113595 logg=5.38
# Changing to T= 50000 for T=137873 logg=5.49
# Changing to logg=5.00 for T=137873 logg=5.49
# Changing to T= 50000 for T=113734 logg=5.39
# Changing to logg=5.00 for T=113734 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T=171676 logg=5.85
# Changing to logg=5.00 for T=171676 logg=5.85
# Changing to T= 50000 for T=113352 logg=5.38
# Changing to logg=5.00 for T=113352 logg=5.38
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=114525 logg=5.39
# Changing to logg=5.00 for T=114525 logg=5.39
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=4.00 for T= 32501 logg=3.83
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27398 logg=3.36
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=142830 logg=5.55
# Changing to logg=5.00 for T=142830 logg=5.55
# Changing to T= 50000 for T=130985 logg=5.41
# Changing to logg=5.00 for T=130985 logg=5.41
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to logg=4.00 for T= 34870 logg=3.73
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27369 logg=3.36
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 26250 logg=3.24
# Changing to T= 50000 for T=131616 logg=5.42
# Changing to logg=5.00 for T=131616 logg=5.42
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=169473 logg=5.84
# Changing to logg=5.00 for T=169473 logg=5.84
# Changing to T= 50000 for T=100152 logg=4.97
# Changing to logg=5.00 for T=100152 logg=4.97
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=137867 logg=5.49
# Changing to logg=5.00 for T=137867 logg=5.49
# Changing to T= 50000 for T=139341 logg=5.51
# Changing to logg=5.00 for T=139341 logg=5.51
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to T= 50000 for T= 95770 logg=4.76
# Changing to logg=5.00 for T= 95770 logg=4.76
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T=145231 logg=5.58
# Changing to logg=5.00 for T=145231 logg=5.58
# Changing to T= 50000 for T=173332 logg=5.87
# Changing to logg=5.00 for T=173332 logg=5.87
# Changing to logg=5.00 for T= 49363 logg=3.80
# Changing to logg=3.50 for T= 28471 logg=3.47
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to logg=4.00 for T= 35259 logg=3.66
# Changing to T= 50000 for T=113993 logg=5.39
# Changing to logg=5.00 for T=113993 logg=5.39
# Changing to logg=3.50 for T= 27428 logg=3.36
# Changing to T= 50000 for T= 52556 logg=3.91
# Changing to logg=5.00 for T= 52556 logg=3.91
# Changing to T= 50000 for T=109797 logg=5.41
# ...
# Changing to logg=4.00 for T= 32024 logg=3.91
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=112365 logg=5.38
# Changing to logg=5.00 for T=112365 logg=5.38
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=4.00 for T= 31791 logg=3.76
# Changing to logg=3.50 for T= 29401 logg=3.47
# Changing to logg=5.00 for T=  1616 logg=4.44
# Changing to logg=4.00 for T= 31791 logg=3.76
# Changing to logg=4.00 for T= 32402 logg=3.91
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to T= 50000 for T=112585 logg=5.38
# Changing to logg=5.00 for T=112585 logg=5.38
# Changing to T= 50000 for T=113211 logg=5.38
# Changing to logg=5.00 for T=113211 logg=5.38
# Changing to logg=4.00 for T= 31935 logg=3.96
# Changing to logg=5.00 for T=  1500 logg=4.44
# Changing to logg=3.50 for T= 27699 logg=3.38
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=4.00 for T= 31527 logg=3.62
# Changing to logg=3.50 for T= 26756 logg=3.28
# Changing to T= 50000 for T=120873 logg=5.27
# Changing to logg=5.00 for T=120873 logg=5.27
# Changing to logg=4.00 for T= 32024 logg=3.91
# Changing to T=  1200 for T=   808 logg=4.44
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to T= 50000 for T=120742 logg=5.26
# Changing to logg=5.00 for T=120742 logg=5.26
# Changing to T= 50000 for T=106238 logg=5.03
# Changing to logg=5.00 for T=106238 logg=5.03
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to logg=3.50 for T= 26756 logg=3.28
# Changing to T= 50000 for T=120731 logg=5.26
# Changing to logg=5.00 for T=120731 logg=5.26
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=4.00 for T= 31935 logg=3.96
# Changing to logg=4.00 for T= 32402 logg=3.91
# Changing to logg=3.50 for T= 27401 logg=3.33
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to logg=3.50 for T= 26632 logg=3.27
# Changing to T= 50000 for T=169141 logg=5.83
# Changing to logg=5.00 for T=169141 logg=5.83
# Changing to T=  1200 for T=   808 logg=4.44
# Changing to T= 50000 for T=113045 logg=5.38
# Changing to logg=5.00 for T=113045 logg=5.38
# Changing to T= 50000 for T=120851 logg=5.26
# Changing to logg=5.00 for T=120851 logg=5.26
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T=  1200 for T=   692 logg=4.44
# Changing to T= 50000 for T=112691 logg=5.38
# Changing to logg=5.00 for T=112691 logg=5.38
# Changing to logg=3.50 for T= 29101 logg=3.46
# Changing to logg=4.00 for T= 32137 logg=3.64
# Changing to logg=4.00 for T= 31820 logg=3.95
# Changing to logg=4.00 for T= 31935 logg=3.96
# Changing to logg=4.00 for T= 32022 logg=3.86
# Changing to logg=4.00 for T= 31846 logg=3.92
# Changing to T= 50000 for T=110461 logg=5.10
# Changing to logg=5.00 for T=110461 logg=5.10
# Changing to T= 50000 for T=113149 logg=5.38
# Changing to logg=5.00 for T=113149 logg=5.38
# Changing to logg=4.00 for T= 31944 logg=3.93
# Changing to logg=5.00 for T=  1500 logg=4.44
# Changing to logg=4.00 for T= 31827 logg=3.99
# Changing to logg=4.00 for T= 31714 logg=3.63
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=4.00 for T= 31265 logg=3.68
# Changing to logg=4.00 for T= 31827 logg=3.99
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=4.00 for T= 31171 logg=4.00
# Changing to T=  1200 for T=   692 logg=4.44
# Changing to logg=4.00 for T= 31171 logg=4.00
# Changing to T= 50000 for T=120909 logg=5.26
# Changing to logg=5.00 for T=120909 logg=5.26
# Changing to logg=4.00 for T= 31566 logg=3.99
# Changing to logg=3.00 for T= 23720 logg=2.97
# Changing to logg=4.00 for T= 31846 logg=3.92
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to logg=4.00 for T= 32022 logg=3.86
# Changing to logg=4.00 for T= 31876 logg=3.75
# Changing to logg=4.00 for T= 31566 logg=3.99
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to logg=4.00 for T= 31820 logg=3.95
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=4.00 for T= 31908 logg=3.94
# Changing to logg=4.00 for T= 31953 logg=3.81
# Changing to T= 50000 for T=112637 logg=5.39
# Changing to logg=5.00 for T=112637 logg=5.39
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=4.00 for T= 31846 logg=3.92
# Changing to logg=4.00 for T= 32022 logg=3.86
# Changing to logg=4.00 for T= 32402 logg=3.91
# Changing to logg=5.00 for T=  1500 logg=4.44
# Changing to T= 50000 for T=120751 logg=5.26
# Changing to logg=5.00 for T=120751 logg=5.26
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=4.00 for T= 31125 logg=3.73
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to logg=4.00 for T= 32022 logg=3.86
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=3.50 for T= 29316 logg=3.50
# Changing to logg=3.50 for T= 29377 logg=3.47
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=4.00 for T= 31171 logg=4.00
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=112826 logg=5.38
# Changing to logg=5.00 for T=112826 logg=5.38
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=4.00 for T= 31876 logg=3.75
# Changing to logg=4.00 for T= 31827 logg=3.99
# Changing to logg=4.00 for T= 31474 logg=3.75
# Changing to T= 50000 for T=109845 logg=5.42
# Changing to logg=5.00 for T=109845 logg=5.42
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=4.00 for T= 31935 logg=3.96
# Changing to T= 50000 for T=112230 logg=5.39
# Changing to logg=5.00 for T=112230 logg=5.39
# Changing to logg=4.00 for T= 32272 logg=3.76
# Changing to logg=4.00 for T= 31953 logg=3.81
# Changing to logg=5.00 for T=  1500 logg=4.44
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=126348 logg=5.37
# Changing to logg=5.00 for T=126348 logg=5.37
# Changing to logg=4.00 for T= 32022 logg=3.86
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to T= 50000 for T=112663 logg=5.38
# Changing to logg=5.00 for T=112663 logg=5.38
# Changing to logg=4.00 for T= 31793 logg=3.76
# Changing to logg=4.00 for T= 32402 logg=3.91
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=4.00 for T= 31953 logg=3.81
# Changing to logg=4.00 for T= 31640 logg=3.75
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=4.00 for T= 31846 logg=3.92
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=4.00 for T= 32034 logg=3.94
# Changing to logg=3.50 for T= 29358 logg=3.47
# Changing to logg=4.00 for T= 33130 logg=3.86
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to logg=3.50 for T= 26555 logg=3.26
# Changing to logg=3.50 for T= 26426 logg=3.28
# Changing to logg=5.00 for T=  1616 logg=4.44
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 26756 logg=3.28
# Changing to T= 50000 for T=121518 logg=5.27
# Changing to logg=5.00 for T=121518 logg=5.27
# Changing to T= 50000 for T=112941 logg=5.38
# Changing to logg=5.00 for T=112941 logg=5.38
# Changing to logg=3.50 for T= 27847 logg=3.28
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=169141 logg=5.83
# Changing to logg=5.00 for T=169141 logg=5.83
# Changing to T=  1200 for T=   750 logg=4.44
# Changing to T=  1200 for T=   692 logg=4.44
# Changing to logg=3.50 for T= 27203 logg=3.35
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to logg=5.00 for T= 49783 logg=3.81
# Changing to T= 50000 for T=106557 logg=5.03
# Changing to logg=5.00 for T=106557 logg=5.03
# Changing to logg=3.50 for T= 26756 logg=3.28
# Changing to logg=4.00 for T= 31283 logg=3.68
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to T= 50000 for T=112577 logg=5.38
# Changing to logg=5.00 for T=112577 logg=5.38
# Changing to logg=5.00 for T=  1616 logg=4.44
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to T= 50000 for T=112987 logg=5.38
# Changing to logg=5.00 for T=112987 logg=5.38
# Changing to logg=4.00 for T= 31791 logg=3.76
# Changing to logg=4.00 for T= 31615 logg=3.93
# Changing to T= 50000 for T=113196 logg=5.38
# Changing to logg=5.00 for T=113196 logg=5.38
# Changing to logg=3.50 for T= 28209 logg=3.14
# Changing to logg=4.50 for T= 48346 logg=3.76
# Changing to logg=4.00 for T= 32172 logg=3.84
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 26541 logg=3.29
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to T= 50000 for T=169134 logg=5.83
# Changing to logg=5.00 for T=169134 logg=5.83
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T=112637 logg=5.38
# Changing to logg=5.00 for T=112637 logg=5.38
# Changing to logg=4.00 for T= 31797 logg=3.85
# Changing to logg=3.50 for T= 28520 logg=3.15
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27397 logg=3.35
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to logg=3.50 for T= 27281 logg=3.32
# Changing to T= 50000 for T= 99378 logg=5.44
# Changing to logg=5.00 for T= 99378 logg=5.44
# Changing to logg=3.50 for T= 28424 logg=3.44
# Changing to logg=4.00 for T= 31846 logg=3.92
# Changing to logg=4.00 for T= 35951 logg=3.82
# Changing to logg=4.00 for T= 31484 logg=3.75
# Changing to logg=3.50 for T= 27281 logg=3.32
# Making photometry for isochrone: log(t) = 6.78  AKs = 2.70  dist = 8000
#      Starting at:  2021-07-22 16:04:20.477486   Usually takes ~5 minutes
# Starting filter: nirc2,Kp   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   1.240 Msun  T =  6076 K  m_nirc2_Kp = 20.09
# M =   1.140 Msun  T =  5867 K  m_nirc2_Kp = 20.41
# M =  17.000 Msun  T = 29494 K  m_nirc2_Kp = 14.17
# M =  16.000 Msun  T = 28747 K  m_nirc2_Kp = 14.28
# M =  14.000 Msun  T = 27689 K  m_nirc2_Kp = 14.71
# M =  12.000 Msun  T = 26167 K  m_nirc2_Kp = 15.18
# M =  18.000 Msun  T = 29349 K  m_nirc2_Kp = 13.88
# M =  19.000 Msun  T = 29973 K  m_nirc2_Kp = 13.78
# M =  25.000 Msun  T = 26250 K  m_nirc2_Kp = 12.38
# M =  30.000 Msun  T =  5885 K  m_nirc2_Kp = 6.06
# M =  17.000 Msun  T = 29494 K  m_nirc2_Kp = 14.17
# M =  11.000 Msun  T = 25047 K  m_nirc2_Kp = 15.35
# M =   1.200 Msun  T =  6043 K  m_nirc2_Kp = 20.05
# M =  19.000 Msun  T = 29973 K  m_nirc2_Kp = 13.78
# M =   0.501 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =  12.000 Msun  T = 26167 K  m_nirc2_Kp = 15.18
# M =  19.000 Msun  T = 29973 K  m_nirc2_Kp = 13.78
# M =  22.000 Msun  T = 29356 K  m_nirc2_Kp = 13.16
# M =  25.000 Msun  T = 26250 K  m_nirc2_Kp = 12.38
# M =   1.400 Msun  T =  6415 K  m_nirc2_Kp = 19.62
# M =  23.000 Msun  T = 28471 K  m_nirc2_Kp = 12.90
# M =  24.000 Msun  T = 27428 K  m_nirc2_Kp = 12.64
# M =   1.300 Msun  T =  6219 K  m_nirc2_Kp = 19.89
# M =  15.000 Msun  T = 28577 K  m_nirc2_Kp = 14.59
# M =   2.512 Msun  T =  2739 K  m_nirc2_Kp = 27.02
# M =  24.000 Msun  T = 27428 K  m_nirc2_Kp = 12.64
# M =  18.000 Msun  T = 28208 K  m_nirc2_Kp = 12.84
# M =   1.500 Msun  T =  6754 K  m_nirc2_Kp = 19.36
# M =   5.012 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   1.400 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   3.162 Msun  T =  2739 K  m_nirc2_Kp = 27.02
# M =  23.000 Msun  T = 28471 K  m_nirc2_Kp = 12.90
# M =   1.200 Msun  T =  6043 K  m_nirc2_Kp = 20.05
# M =   1.400 Msun  T =  6455 K  m_nirc2_Kp = 19.61
# M =  15.000 Msun  T = 28577 K  m_nirc2_Kp = 14.59
# M =  14.000 Msun  T = 26861 K  m_nirc2_Kp = 12.47
# M =  23.000 Msun  T = 28471 K  m_nirc2_Kp = 12.90
# M =   3.162 Msun  T =  2739 K  m_nirc2_Kp = 27.02
# M =   7.943 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   3.981 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =  24.000 Msun  T = 27428 K  m_nirc2_Kp = 12.64
# M =  16.000 Msun  T = 28747 K  m_nirc2_Kp = 14.28
# M =   5.012 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   1.400 Msun  T =  6455 K  m_nirc2_Kp = 19.61
# M =  17.000 Msun  T = 29494 K  m_nirc2_Kp = 14.17
# M =  19.000 Msun  T = 29973 K  m_nirc2_Kp = 13.78
# M =   5.012 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =  12.000 Msun  T = 26167 K  m_nirc2_Kp = 15.18
# M =  18.000 Msun  T = 29349 K  m_nirc2_Kp = 13.88
# M =   1.400 Msun  T =  6455 K  m_nirc2_Kp = 19.61
# M =  21.000 Msun  T = 33630 K  m_nirc2_Kp = 13.18
# M =  17.000 Msun  T = 29494 K  m_nirc2_Kp = 14.17
# M =   1.259 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =  16.000 Msun  T = 28747 K  m_nirc2_Kp = 14.28
# M =   3.162 Msun  T =  2739 K  m_nirc2_Kp = 27.02
# M =  12.000 Msun  T = 26167 K  m_nirc2_Kp = 15.18
# M =  17.000 Msun  T = 29494 K  m_nirc2_Kp = 14.17
# M =  13.600 Msun  T = 29508 K  m_nirc2_Kp = 15.06
# M =  12.800 Msun  T = 28723 K  m_nirc2_Kp = 15.19
# M =   5.600 Msun  T = 18331 K  m_nirc2_Kp = 17.04
# M =   6.000 Msun  T = 19094 K  m_nirc2_Kp = 16.91
# M =  10.800 Msun  T = 26504 K  m_nirc2_Kp = 15.63
# M =   3.800 Msun  T = 14375 K  m_nirc2_Kp = 17.79
# M =  15.000 Msun  T = 30594 K  m_nirc2_Kp = 14.75
# M =  27.000 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   6.800 Msun  T = 20549 K  m_nirc2_Kp = 16.66
# M =   9.900 Msun  T = 25356 K  m_nirc2_Kp = 15.83
# M =   0.600 Msun  T =  3462 K  m_nirc2_Kp = 22.15
# M =   9.500 Msun  T = 24770 K  m_nirc2_Kp = 15.95
# M =   1.700 Msun  T =  7729 K  m_nirc2_Kp = 19.20
# M =   2.400 Msun  T = 10466 K  m_nirc2_Kp = 18.70
# M =   5.700 Msun  T = 18521 K  m_nirc2_Kp = 17.01
# M =  13.200 Msun  T = 29129 K  m_nirc2_Kp = 15.13
# M =  10.000 Msun  T = 25463 K  m_nirc2_Kp = 15.82
# M =   1.120 Msun  T =  5956 K  m_nirc2_Kp = 20.47
# M =   9.200 Msun  T = 24356 K  m_nirc2_Kp = 16.01
# M =  16.800 Msun  T = 31566 K  m_nirc2_Kp = 14.37
# M =   0.260 Msun  T =  1500 K  m_nirc2_Kp = 25.95
# M =  12.000 Msun  T = 27889 K  m_nirc2_Kp = 15.40
# M =  25.000 Msun  T = 26756 K  m_nirc2_Kp = 12.44
# M =  14.400 Msun  T = 30152 K  m_nirc2_Kp = 14.87
# M =   5.400 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   0.450 Msun  T =  3703 K  m_nirc2_Kp = 23.33
# M =  24.000 Msun  T = 28424 K  m_nirc2_Kp = 12.77
# M =  11.000 Msun  T = 25256 K  m_nirc2_Kp = 15.42
# M =  15.000 Msun  T = 28732 K  m_nirc2_Kp = 14.62
# M =  20.700 Msun  T = 31791 K  m_nirc2_Kp = 13.58
# M =   0.960 Msun  T =  5540 K  m_nirc2_Kp = 20.67
# M =   0.980 Msun  T =  5655 K  m_nirc2_Kp = 20.62
# M =  12.000 Msun  T = 27889 K  m_nirc2_Kp = 15.40
# M =  11.200 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =  20.700 Msun  T = 31791 K  m_nirc2_Kp = 13.58
# M =  15.000 Msun  T = 28732 K  m_nirc2_Kp = 14.62
# M =  30.000 Msun  T = 113092 K  m_nirc2_Kp = 18.02
# M =  18.000 Msun  T = 29019 K  m_nirc2_Kp = 13.94
# M =   7.200 Msun  T = 21244 K  m_nirc2_Kp = 16.54
# M =  14.400 Msun  T = 30092 K  m_nirc2_Kp = 14.84
# M =  21.000 Msun  T = 29443 K  m_nirc2_Kp = 13.31
# M =   0.140 Msun  T =   808 K  m_nirc2_Kp = 27.79
# M =   3.400 Msun  T = 13359 K  m_nirc2_Kp = 18.01
# M =   7.600 Msun  T = 21902 K  m_nirc2_Kp = 16.43
# M =  14.000 Msun  T = 27852 K  m_nirc2_Kp = 14.74
# M =   6.000 Msun  T = 19094 K  m_nirc2_Kp = 16.91
# M =   1.800 Msun  T =  8304 K  m_nirc2_Kp = 19.22
# M =   0.560 Msun  T =  3231 K  m_nirc2_Kp = 22.47
# M =   6.300 Msun  T =   nan K  m_nirc2_Kp =  nan
# M =   3.400 Msun  T = 13359 K  m_nirc2_Kp = 18.01
# M =   1.500 Msun  T =  6795 K  m_nirc2_Kp = 19.36
# M =  11.200 Msun  T = 26992 K  m_nirc2_Kp = 15.54
# M =  22.000 Msun  T = 28473 K  m_nirc2_Kp = 13.02
# M =  10.800 Msun  T = 26480 K  m_nirc2_Kp = 15.65
# M =   5.100 Msun  T = 17313 K  m_nirc2_Kp = 17.22
#       Time taken: 15.06 seconds
# Isochrone generation took 677.063699 s.

# %%
from spisea import imf, ifmr, evolution
import numpy as np
# If we want to use control group, let's use multiplicity = None.
custom_IMF = imf.imf.IMF_broken_powerlaw(np.array([1, 150]),
                                         np.array([-2.35]),
                                         multiplicity=
                                         (imf.multiplicity.
                                          MultiplicityUnresolved()))
import time
t1 = time.time()
BPASS_Cluster = synthetic.Cluster_w_Binaries(BPASS_iso, custom_IMF,
                                             1000000,
                                             ifmr=None)
t2 = time.time()
t_time = t2 - t1
# Out:
# /u/ryotainagaki/Desktop/PyPopStar/spisea/synthetic.py:752: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   compMass = np.array([compMass[x] for x in indices])
# Interpolation for: Teff
# Interpolation for: L
# Interpolation for: logg
# Interpolation for: isWR
# Interpolation for: mass_current
# Interpolation for: phase
# Interpolation for: m_nirc2_Kp
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/table.py:3197: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   result = self.as_array() == other

# %% [markdown]
# Then, I create the scaling factor we use to turn number of stars in a magnitude bin
# to area (arcsecond^2) density of stars in a magnitude bin.

# %%
area = 150  # arcsec^2
# Think of how many stars per area would there be in a similar cluster
# but with lower mass. We use scaling.
scaleFactorBPS = ((17000 /
                   1e6) /
                  area)
print(scaleFactorBPS)
# Out:
# 0.00011333333333333334

# %% [markdown]
# In the next cell, I make sure that I am NOT including WR stars in my plots and that I am not including stars with magnitudes greater than cutoff (K' = 15.5)
# here, I want to make an array like object of individual BPASS stars' magnitudes (not necessarily just of star systems)

# %%
totl_BPASS = (BPASS_Cluster.star_systems['m_nirc2_Kp']
               [np.where((BPASS_Cluster.star_systems['isWR']==0))[0]])

# %% [markdown]
# Below, I produce my first plot that demonstrates the problem with BPASS's IMF. I also set up bins and BPASS weights, which I will use in the next figure.

# %%
import matplotlib.pyplot as py
# Primary star fluxes
klf_mag_bins = np.arange(9.0, 17, 1.0)
binsKp = klf_mag_bins
binEdges = binsKp[0:-1] + (binsKp[1:] - binsKp[0:-1]) / 2.0

weightsBPS = np.array([1.0 for x in totl_BPASS])
weightsBPS *= scaleFactorBPS
(n1, b1, p1) = py.hist(totl_BPASS, bins=binEdges, weights=weightsBPS,
                       histtype='step', color='green',
                       label='BPASS Stars', align='mid',
                       linewidth=1.5)
py.errorbar(result.Kp[idx],
            result.KLF_ext_cmp_sp_im_noWR[idx],
            fmt='ro-', xerr=magBin/2.0, linewidth=2)
py.errorbar(result.Kp[idx], result.KLF_ext_cmp_sp_im_noWR[idx],
            fmt='ro-', yerr=result.eKLF_ext_cmp_sp_im_noWR[idx],
            linewidth=2,
            label='Observed')
py.legend(loc='upper left', numpoints=1)
py.xlabel('Kp magnitude')
py.ylabel('Stars / (arcsec^2 mag)')
py.title('KLF of clusters at Age = %d Myr (Using MultiplicityUnresolved and \n Using Salpeter 1955 IMF)' % (10**(6.78 - 6)),
         fontsize=14)
# Out:
# Text(0.5, 1.0, 'KLF of clusters at Age = 6 Myr (Using MultiplicityUnresolved and \n Using Salpeter 1955 IMF)')
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Bitstream Vera Sans
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Bitstream Vera Sans
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Bitstream Vera Sans

# %% [markdown]
# **Now I create the MIST v1 cluster and then make the final figure of the talk.**

# %%
MIST_iso = synthetic.IsochronePhot(6.78, 2.7, 8000, 0.0,
                                   min_mass = 1.0,
                                   max_mass = 150, recomp=False,
                                   filters=['nirc2,Kp'])
MIST_Cluster = synthetic.ResolvedCluster(MIST_iso, custom_IMF,
                                         1000000,
                                         ifmr=None)
Merged_iso = synthetic.IsochronePhot(6.78, 2.7, 8000, 0.0,
                                     evo_model=evolution.MergedBaraffePisaEkstromParsec(),
                                     min_mass = 1.0,
                                     max_mass = 150, recomp=False,
                                     filters=['nirc2,Kp'])
Merged_Clus = synthetic.ResolvedCluster(Merged_iso, custom_IMF,
                                         1000000,
                                         ifmr=None)
# Out:
# Found 1599 stars out of mass range

# %% [markdown]
# In the next cell, I make sure that I am NOT including WR stars in my plots and that I am not including stars with magnitudes greater than cutoff (K' = 15.5)
# here, I want to make an array like object of individual MIST stars' magnitudes (not necessarily just of star systems)

# %%
totl_mist = (MIST_Cluster.star_systems['m_nirc2_Kp']
             [np.where((MIST_Cluster.star_systems['isWR'] == 0))[0]])
totl_merged = (Merged_Clus.star_systems['m_nirc2_Kp']
               [np.where((Merged_Clus.star_systems['isWR'] == 0))[0]])
# Now find the magintudes of just the primary star

# %%
import matplotlib.pyplot as py

# Setting up framework so that I can scale the number of stars in mass bin
# into density: number of stars per square arcsecond.

# I won't be using the sum of initial masses of only existing stars for
# the scale factors
mist_scale = scaleFactorBPS
merged_scale = scaleFactorBPS

weights_MST = np.array([1.0 for x in totl_mist], dtype=np.float64)
weights_MST *= mist_scale
weights_merged = np.array([1.0 for x in totl_merged])
weights_merged *= merged_scale
# Binning the K' magnitudes into their respective bins

py.hist(totl_mist, bins=binEdges, histtype='step',
        weights=weights_MST, color='green', label='MISTv.1 Model',
        align='mid', linewidth=1.5)
py.hist(totl_BPASS, bins=binEdges, histtype='step',
        weights=weightsBPS, color='blue',
        label='BPASS Model KLF',
        align='mid', linewidth=1.5)
py.hist(totl_merged, bins=binEdges, histtype='step',
        weights=weights_merged, color='orange',
        label='Merged Model KLF',
        align='mid', linewidth=1.5)
py.errorbar(result.Kp[idx], result.KLF_ext_cmp_sp_im_noWR[idx],
            fmt='ro-', xerr=magBin/2.0, capsize=0, linewidth=2)
py.errorbar(result.Kp[idx],result.KLF_ext_cmp_sp_im_noWR[idx],
            fmt='ro-', yerr=result.eKLF_ext_cmp_sp_im_noWR[idx],
            linewidth=2,
       label='Observed')
py.xlim(8.5, 15.5)
py.xlabel('Kp magnitude')
py.ylabel("stars / (arcsecond^2 mag)")
py.title("KLF's at Age = %d Myr Using MultiplicityUnresolved" % (10**(6.78 - 6))+
         "\n (Using Salpeter 1955 IMF)", fontsize=14)
py.legend(loc='upper left', numpoints=1)
py.savefig("StillBadKLF1Salpt.png")

# %% [markdown]
# Now trying to explore which stars had their mass_current interpolated properly and which did not.

# %% [markdown]
# Since I don't like doing copy paste and making a bunch of copies (and increasing my chances of making my typographic errors), I will generate plotting as a function! This should make life easy!

# %%
title_default = "Plot of primary secondary pairs of BPASS isochrone and cluster"

def plot_scatter(clus, x_lim, y_lim, label1, label2, title, savefile):
    py.figure(figsize = (12, 12))
    py.plot(clus.rejected_prims,
            clus.rejected_sec,
            "r+",  label=label1)
    py.plot(clus.good_systems[:, 0],
            clus.good_systems[:, 1],
            "g+", label=label2)
    py.plot(clus.iso.primaries['mass'],
            clus.iso.secondaries['mass'],
            "k*", label="primary-secondary pair intial masses of stars from isochrone")
    py.xlim(x_lim[0], x_lim[1])
    py.ylim(y_lim[0], y_lim[1])
    py.xlabel("Primary star intial mass in $M_{\odot}$")
    py.ylabel("Secondary star intial mass in $M_{\odot}$")
    py.title(title)
    py.legend(prop={'size' : 11})
    py.savefig(savefile)

# %% [markdown]
# Now what is the joint distribution of primaries and secondaries pairs that did not interpolate mass_current properly?

# %%
label1 = ("primary-secondary star pairs where " +
          "mass_current of a star in the pair\n " +
          "was interpolated to be nan \n (Not included merged pairs)")
label2 = ("star sytems (primary-secondary star pairs) that" +
          " are merged\n or have non-Nan mass_current")
plot_scatter(BPASS_Cluster, (0, 40.0), (0, 40.0), label1,
             label2,
             title_default + "\n (Using mass_current to check interpolation)",
             "Scatter1SalptZoomed0.png")

# %%
plot_scatter(BPASS_Cluster, (0, 10.0), (0, 10.0),
             label1, label2,
             title_default + "\n (Using mass_current to check interpolation and zoomed in)",
             "Scatter1SalptZoomed1.png")

# %% [markdown]
# Now trying to explore which stars had their logg interpolated properly and which did not.

# %%
BPASS_Cluster = synthetic.Cluster_w_Binaries(BPASS_iso, custom_IMF,
                                             1000000,
                                             ifmr=None, tests='logg')

# %%
label1=("primary-secondary star pairs where " +
        "logg of a star in the pair\n " +
        "was interpolated to be nan \n (Not included merged pairs)")
label2=("star sytems (primary-secondary star pairs) that \n" +
        "are merged\n or have logg that is non-Nan")
plot_scatter(BPASS_Cluster, (0, 40.0), (0, 40.0), label1,
             label2,
             title_default + "\n (Using logg to check interpolation)",
             "ScatterLoggSalptZoomed0.png")

# %%
plot_scatter(BPASS_Cluster, (0, 10.0), (0, 10.0), label1,
             label2,
             title_default + "\n (Using logg to check interpolation and Zoomed-In)",
             "ScatterLoggSalptZoomed1.png")

# %% [markdown]
# Now trying to explore which stars had their Teff interpolated properly and which did not. Note that I did have to change the algorithm determining that as effective temperature can equal a NaN value when the star is a compact remnant.

# %%
BPASS_Cluster = synthetic.Cluster_w_Binaries(BPASS_iso, custom_IMF,
                                             1000000,
                                             ifmr=None, tests='Teff')

# %%
label1=("primary-secondary star pairs where" +
        "Teff of a star in the pair\n " +
        "was interpolated to be nan \n (Not including merged pairs and \n " +
        "not including star pairs with compact remnants)")
label2=("star sytems (primary-secondary star pairs) that" +
        " are merged\n or have non-Nan Teff")
plot_scatter(BPASS_Cluster, (0, 40.0), (0, 40.0), label1,
             label2, title_default + "\n (Using Teff to check interpolation)",
             "Scatter1TeffSalpt.png")

# %%
plot_scatter(BPASS_Cluster, (0, 10.0), (0, 10.0), label1,
             label2,
             title_default + "\n (Using Teff to check interpolation and Zoomed-In)",
             "Scatter1TeffZoomed1Salpt.png")

# %% [markdown]
# Now trying to explore which stars had their L interpolated properly and which did not. Note that I did have to change the algorithm determining that as a star's luminosity can equal a NaN value when the star is a compact remnant.

# %%
BPASS_Cluster = synthetic.Cluster_w_Binaries(BPASS_iso, custom_IMF,
                                             1000000,
                                             ifmr=None, tests='L')

# %%
label1=("primary-secondary star pairs where " +
        "L of a star in the pair\n " +
        "was interpolated to be nan \n (Not including merged pairs and \n " +
        "not including star pairs with compact remnants)")
label2=("star sytems (primary-secondary star pairs) that" +
        " are merged\n or have non-Nan L")
plot_scatter(BPASS_Cluster, (0, 40.0), (0, 40.0), label1,
             label2,
             title_default + "\n (Using L to check interpolation and Zoomed-In)",
             "Scatter1LSalpt.png")

# %%
plot_scatter(BPASS_Cluster, (0, 10.0), (0, 10.0), label1,
             label2,title_default + "\n (Using L to check interpolation and Zoomed-In)",
             "Scatter1LSalptZoomedIn.png")
